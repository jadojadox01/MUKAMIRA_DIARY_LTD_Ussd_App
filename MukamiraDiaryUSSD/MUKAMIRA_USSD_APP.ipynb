# %%
import mysql.connector

def connect_db():
    return mysql.connector.connect(
        host="localhost",
        user="root",
        password="",
        database="Milk_store"
    )

def register_customer():
    connection = connect_db()
    cursor = connection.cursor()
    
    print("Customer Registration")
    email = input("Enter your email: ")
    phone = input("Enter your phone number: ")
    road_nbr = input("Enter your road number: ")

    cursor.execute(
        "INSERT INTO Customers (Email, Phone, Road_nbr) VALUES (%s, %s, %s)",
        (email, phone, road_nbr)
    )
    connection.commit()
    print("Registration successful!")
    cursor.close()
    connection.close()

def login_customer():
    connection = connect_db()
    cursor = connection.cursor()

    print("Customer Login")
    phone = input("Enter your phone number: ")

    cursor.execute("SELECT C_id FROM Customers WHERE Phone = %s", (phone,))
    result = cursor.fetchone()
    
    if result:
        customer_id = result[0]
        print("Login successful!")
        cursor.close()
        connection.close()
        return customer_id
    else:
        print("Customer not found. Please register.")
        cursor.close()
        connection.close()
        return None

def place_order(customer_id):
    connection = connect_db()
    cursor = connection.cursor()

    print("WELCOME TO MUKAMIRA DIARY LTD")
    print("1. Place Order")
    print("2. Exit")
    choice = input("Choose an option: ")

    if choice == '2':
        print("Exiting...")
        return

    # Step 2: Select a product
    print("SELECT A PRODUCT:\n")
    cursor.execute("SELECT P_name FROM products")
    products = cursor.fetchall()

    for idx, product in enumerate(products, start=1):
        print(f"{idx}. {product[0]}")

    product_choice = int(input("Choose a product: ")) - 1
    selected_product = products[product_choice][0]

    # Step 3: Select a size
    print("SELECT SIZE")
    sizes = ["250 ml", "1L", "3L"]
    for idx, size in enumerate(sizes, start=1):
        print(f"{idx}. {size}")

    size_choice = int(input("Choose a size: ")) - 1
    selected_size = sizes[size_choice]

    # Step 4: Confirm order
    order_amount = int(input("Enter Order amount: "))
    cursor.execute("SELECT P_unitprice FROM products WHERE P_name = %s", (selected_product,))
    unit_price = cursor.fetchone()[0]
    total_price = order_amount * unit_price

    # Display order summary
    print("Confirm Order:")
    print(f"Product_Name: {selected_product}")
    print(f"Size: {selected_size}")
    print(f"Order_Amount: {order_amount}")
    print(f"Total_Price: {total_price}")
    print("1. Confirm")
    print("2. Cancel")

    final_choice = input("Choose an option: ")

    if final_choice == '1':
        cursor.execute(
            "INSERT INTO Orders (C_id, Order_amount, Order_totalprice) VALUES (%s, %s, %s)",
            (customer_id, order_amount, total_price)
        )
        connection.commit()
        print("Order placed successfully!")
    else:
        print("Order cancelled.")

    cursor.close()
    connection.close()

def main():
    while True:
        print("1. Register")
        print("2. Login")
        print("3. Exit")
        choice = input("Choose an option: ")

        if choice == '1':
            register_customer()
        elif choice == '2':
            customer_id = login_customer()
            if customer_id:
                place_order(customer_id)
                break  # Exit the loop after placing an order
        elif choice == '3':
            print("Exiting...")
            break
        else:
            print("Invalid choice, please try again.")

if __name__ == "__main__":
    main()
# Out:
# 1. Register
# 2. Login
# 3. Exit
# Invalid choice, please try again.
# 1. Register
# 2. Login
# 3. Exit
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File c:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\mysql\connector\connection_cext.py:323, in CMySQLConnection._open_connection(self)
#     322 try:
# --> 323     self._cmysql.connect(**cnx_kwargs)
#     324     self._cmysql.converter_str_fallback = self._converter_str_fallback
#
# MySQLInterfaceError: Unknown MySQL server host 'your_host' (11001)
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# d:\MukamiraDiaryUSSD\MUKAMIRA_USSD_APP.ipynb Cell 1 line 1
#     <a href='vscode-notebook-cell:/d%3A/MukamiraDiaryUSSD/MUKAMIRA_USSD_APP.ipynb#W1sZmlsZQ%3D%3D?line=131'>132</a>             print("Invalid choice, please try again.")
#     <a href='vscode-notebook-cell:/d%3A/MukamiraDiaryUSSD/MUKAMIRA_USSD_APP.ipynb#W1sZmlsZQ%3D%3D?line=133'>134</a> if __name__ == "__main__":
# --> <a href='vscode-notebook-cell:/d%3A/MukamiraDiaryUSSD/MUKAMIRA_USSD_APP.ipynb#W1sZmlsZQ%3D%3D?line=134'>135</a>     main()
#
# d:\MukamiraDiaryUSSD\MUKAMIRA_USSD_APP.ipynb Cell 1 line 1
#     <a href='vscode-notebook-cell:/d%3A/MukamiraDiaryUSSD/MUKAMIRA_USSD_APP.ipynb#W1sZmlsZQ%3D%3D?line=118'>119</a> choice = input("Choose an option: ")
#     <a href='vscode-notebook-cell:/d%3A/MukamiraDiaryUSSD/MUKAMIRA_USSD_APP.ipynb#W1sZmlsZQ%3D%3D?line=120'>121</a> if choice == '1':
# --> <a href='vscode-notebook-cell:/d%3A/MukamiraDiaryUSSD/MUKAMIRA_USSD_APP.ipynb#W1sZmlsZQ%3D%3D?line=121'>122</a>     register_customer()
#     <a href='vscode-notebook-cell:/d%3A/MukamiraDiaryUSSD/MUKAMIRA_USSD_APP.ipynb#W1sZmlsZQ%3D%3D?line=122'>123</a> elif choice == '2':
#     <a href='vscode-notebook-cell:/d%3A/MukamiraDiaryUSSD/MUKAMIRA_USSD_APP.ipynb#W1sZmlsZQ%3D%3D?line=123'>124</a>     customer_id = login_customer()
#
# d:\MukamiraDiaryUSSD\MUKAMIRA_USSD_APP.ipynb Cell 1 line 1
#      <a href='vscode-notebook-cell:/d%3A/MukamiraDiaryUSSD/MUKAMIRA_USSD_APP.ipynb#W1sZmlsZQ%3D%3D?line=10'>11</a> def register_customer():
# ---> <a href='vscode-notebook-cell:/d%3A/MukamiraDiaryUSSD/MUKAMIRA_USSD_APP.ipynb#W1sZmlsZQ%3D%3D?line=11'>12</a>     connection = connect_db()
#      <a href='vscode-notebook-cell:/d%3A/MukamiraDiaryUSSD/MUKAMIRA_USSD_APP.ipynb#W1sZmlsZQ%3D%3D?line=12'>13</a>     cursor = connection.cursor()
#      <a href='vscode-notebook-cell:/d%3A/MukamiraDiaryUSSD/MUKAMIRA_USSD_APP.ipynb#W1sZmlsZQ%3D%3D?line=14'>15</a>     print("Customer Registration")
#
# d:\MukamiraDiaryUSSD\MUKAMIRA_USSD_APP.ipynb Cell 1 line 4
#       <a href='vscode-notebook-cell:/d%3A/MukamiraDiaryUSSD/MUKAMIRA_USSD_APP.ipynb#W1sZmlsZQ%3D%3D?line=2'>3</a> def connect_db():
# ----> <a href='vscode-notebook-cell:/d%3A/MukamiraDiaryUSSD/MUKAMIRA_USSD_APP.ipynb#W1sZmlsZQ%3D%3D?line=3'>4</a>     return mysql.connector.connect(
#       <a href='vscode-notebook-cell:/d%3A/MukamiraDiaryUSSD/MUKAMIRA_USSD_APP.ipynb#W1sZmlsZQ%3D%3D?line=4'>5</a>         host="your_host",
#       <a href='vscode-notebook-cell:/d%3A/MukamiraDiaryUSSD/MUKAMIRA_USSD_APP.ipynb#W1sZmlsZQ%3D%3D?line=5'>6</a>         user="your_username",
#       <a href='vscode-notebook-cell:/d%3A/MukamiraDiaryUSSD/MUKAMIRA_USSD_APP.ipynb#W1sZmlsZQ%3D%3D?line=6'>7</a>         password="your_password",
#       <a href='vscode-notebook-cell:/d%3A/MukamiraDiaryUSSD/MUKAMIRA_USSD_APP.ipynb#W1sZmlsZQ%3D%3D?line=7'>8</a>         database="Milk_store"
#       <a href='vscode-notebook-cell:/d%3A/MukamiraDiaryUSSD/MUKAMIRA_USSD_APP.ipynb#W1sZmlsZQ%3D%3D?line=8'>9</a>     )
#
# File c:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\mysql\connector\pooling.py:322, in connect(*args, **kwargs)
#     319         raise ImportError(ERROR_NO_CEXT)
#     321 if CMySQLConnection and not use_pure:
# --> 322     return CMySQLConnection(*args, **kwargs)
#     323 return MySQLConnection(*args, **kwargs)
#
# File c:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\mysql\connector\connection_cext.py:140, in CMySQLConnection.__init__(self, **kwargs)
#     138 if kwargs:
#     139     try:
# --> 140         self.connect(**kwargs)
#     141     except Exception:
#     142         self.close()
#
# File c:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\mysql\connector\abstracts.py:1363, in MySQLConnectionAbstract.connect(self, **kwargs)
#    1360     self.config(**kwargs)
#    1362 self.disconnect()
# -> 1363 self._open_connection()
#    1365 charset, collation = (
#    1366     kwargs.pop("charset", None),
#    1367     kwargs.pop("collation", None),
#    1368 )
#    1369 if charset or collation:
#
# File c:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\mysql\connector\connection_cext.py:328, in CMySQLConnection._open_connection(self)
#     326         self.converter.str_fallback = self._converter_str_fallback
#     327 except MySQLInterfaceError as err:
# --> 328     raise get_mysql_exception(
#     329         msg=err.msg, errno=err.errno, sqlstate=err.sqlstate
#     330     ) from err
#     332 self._do_handshake()
#
# DatabaseError: 2005 (HY000): Unknown MySQL server host 'your_host' (11001)
